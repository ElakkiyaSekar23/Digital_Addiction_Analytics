# %%
import pandas as pd

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/user_behavior_dataset.csv")

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User ID                     700 non-null    int64
#  1   Device Model                700 non-null    str
#  2   Operating System            700 non-null    str
#  3   App Usage Time (min/day)    700 non-null    int64
#  4   Screen On Time (hours/day)  700 non-null    float64
#  5   Battery Drain (mAh/day)     700 non-null    int64
#  6   Number of Apps Installed    700 non-null    int64
#  7   Data Usage (MB/day)         700 non-null    int64
#  8   Age                         700 non-null    int64
#  9   Gender                      700 non-null    str
#  10  User Behavior Class         700 non-null    int64
# dtypes: float64(1), int64(7), str(3)
# memory usage: 76.3 KB

# %%
df.columns
# Out:
# Index(['User ID', 'Device Model', 'Operating System',
#        'App Usage Time (min/day)', 'Screen On Time (hours/day)',
#        'Battery Drain (mAh/day)', 'Number of Apps Installed',
#        'Data Usage (MB/day)', 'Age', 'Gender', 'User Behavior Class'],
#       dtype='str')

# %%
df.describe()
# Out:
#          User ID  App Usage Time (min/day)  Screen On Time (hours/day)  \
# count  700.00000                700.000000                  700.000000
# mean   350.50000                271.128571                    5.272714
# std    202.21688                177.199484                    3.068584
# min      1.00000                 30.000000                    1.000000
# 25%    175.75000                113.250000                    2.500000
# 50%    350.50000                227.500000                    4.900000
# 75%    525.25000                434.250000                    7.400000
# max    700.00000                598.000000                   12.000000
#
#        Battery Drain (mAh/day)  Number of Apps Installed  Data Usage (MB/day)  \
# count               700.000000                700.000000           700.000000
# mean               1525.158571                 50.681429           929.742857
# std                 819.136414                 26.943324           640.451729
# ...

# %%
df["Device Model"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df["Device Model"].value_counts()
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv("../data/user_behavior_dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("../data/user_behavior_dataset.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/user_behavior_dataset.csv")

# %%
df["Device Model"].value_counts()
# Out:
# Device Model
# Xiaomi Mi 11          146
# iPhone 12             146
# Google Pixel 5        142
# OnePlus 9             133
# Samsung Galaxy S21    133
# Name: count, dtype: int64

# %%
df.groupby("Operating System")["App Usage Time (min/day)"].mean()
# Out:
# Operating System
# Android    268.258123
# iOS        282.020548
# Name: App Usage Time (min/day), dtype: float64

# %%
df["Operating System"].value_counts()
# Out:
# Operating System
# Android    554
# iOS        146
# Name: count, dtype: int64

# %%
df.groupby("Operating System")["App Usage Time (min/day)"].mean().round(2)
# Out:
# Operating System
# Android    268.26
# iOS        282.02
# Name: App Usage Time (min/day), dtype: float64

# %%
df[["Screen On Time (hours/day)", "App Usage Time (min/day)"]].corr()
# Out:
#                             Screen On Time (hours/day)  \
# Screen On Time (hours/day)                    1.000000
# App Usage Time (min/day)                      0.950333
#
#                             App Usage Time (min/day)
# Screen On Time (hours/day)                  0.950333
# App Usage Time (min/day)                    1.000000

# %%
df[["App Usage Time (min/day)", "Battery Drain (mAh/day)"]].corr()
# Out:
#                           App Usage Time (min/day)  Battery Drain (mAh/day)
# App Usage Time (min/day)                  1.000000                 0.956385
# Battery Drain (mAh/day)                   0.956385                 1.000000

# %%
df["User Behavior Class"].value_counts()
# Out:
# User Behavior Class
# 2    146
# 3    143
# 4    139
# 5    136
# 1    136
# Name: count, dtype: int64

# %%
df.groupby("User Behavior Class")[
    "App Usage Time (min/day)"
].mean().round(2)
# Out:
# User Behavior Class
# 1     60.43
# 2    131.97
# 3    235.40
# 4    395.75
# 5    541.42
# Name: App Usage Time (min/day), dtype: float64

# %%
df.groupby("User Behavior Class")[
    "Screen On Time (hours/day)"
].mean().round(2)
# Out:
# User Behavior Class
# 1     1.49
# 2     3.04
# 3     4.96
# 4     6.91
# 5    10.11
# Name: Screen On Time (hours/day), dtype: float64

# %%
df.groupby("Gender")["Age"].mean().round(2)
# Out:
# Gender
# Female    38.40
# Male      38.56
# Name: Age, dtype: float64

# %%
df.groupby("Device Model")[
    "Screen On Time (hours/day)"
].mean().round(2)
# Out:
# Device Model
# Google Pixel 5        5.08
# OnePlus 9             5.24
# Samsung Galaxy S21    5.32
# Xiaomi Mi 11          5.29
# iPhone 12             5.43
# Name: Screen On Time (hours/day), dtype: float64

# %%
df.groupby("User Behavior Class")[
    "Battery Drain (mAh/day)"
].mean().round(2)
# Out:
# User Behavior Class
# 1     454.98
# 2     883.81
# 3    1515.06
# 4    2105.81
# 5    2701.01
# Name: Battery Drain (mAh/day), dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
df["Operating System"].value_counts().plot(kind="bar")
plt.show()

# %%
df.groupby("Operating System")[
    "App Usage Time (min/day)"
].mean().plot(kind="bar")

plt.show()
